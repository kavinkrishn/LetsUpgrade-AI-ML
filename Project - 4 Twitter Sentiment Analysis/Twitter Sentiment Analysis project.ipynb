# %%
# !pip install tweepy
# Out:
# ...
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# ...

# %%
# !pip install openpyxl

# %%
import numpy as np
import pandas as pd
import tweepy
import json
from tweepy import OAuthHandler

# %%
consumer_key ="enn1AGodU9VRoA3dm4tXR1Uf8"
consumer_secret = "7QQKIj94tNy79gioOpbwBuKXjetIo8OrueKldPGGlQaqobDaGq"
access_token = "366148828-fB8M8Z4KC5ZN3n7UA38tMGMUCOz9derwwaKrBYsM"
access_token_secret = "5ocafyanKNp7bsNpJrhDOGQvQwG8dMti7KTg1iYVBVD5r"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
query = " ipl T20 2020"

# %%
Tweets = api.search(query, count=10, lang='en', exclude='retweets',tweet_mode='extended')

for tweet in Tweets:
    print(tweet,"\n")
    print(".........................\n")
# Out:
# Status(_api=<tweepy.api.API object at 0x0000019CA5BF3F08>, _json={'created_at': 'Sat Oct 31 06:10:18 +0000 2020', 'id': 1322420613751971840, 'id_str': '1322420613751971840', 'full_text': '1000 T20 sixes ✅\nMatch fee deducted ❌\n\nDetails here: https://t.co/lPX1VNDfM0\n\nPlay your next Fantasy Contest on https://t.co/qTR0FqGRau\n\n#ChrisGayle  #cricket # GoodGamer #KX1PvsRR https://t.co/fbmStB2wt4', 'truncated': False, 'display_text_range': [0, 180], 'entities': {'hashtags': [{'text': 'ChrisGayle', 'indices': [137, 148]}, {'text': 'cricket', 'indices': [150, 158]}, {'text': 'KX1PvsRR', 'indices': [171, 180]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/lPX1VNDfM0', 'expanded_url': 'http://ow.ly/10Dy50C7RmU', 'display_url': 'ow.ly/10Dy50C7RmU', 'indices': [53, 76]}, {'url': 'https://t.co/qTR0FqGRau', 'expanded_url': 'http://goodgamer.in', 'display_url': 'goodgamer.in', 'indices': [112, 135]}], 'media': [{'id': 1322420611805753345, 'id_str': '1322420611805753345'
# ...

# %%
df = pd.DataFrame(columns = ['Tweets' , 'User' , 'User_statuses_count' ,'user_followers' , 'User_location' , 'User_verified' ,
                            'fav_count' , 'rt_count' , 'tweet_date'])
print(df)
# Out:
# Empty DataFrame
# Columns: [Tweets, User, User_statuses_count, user_followers, User_location, User_verified, fav_count, rt_count, tweet_date]
# Index: []

# %%
def stream(data,file_name):
    i = 0
    for tweet in tweepy.Cursor(api.search, q=data, count=100, lang='en').items():
        print(i, end='\r')
        df.loc[i, 'Tweets'] = tweet.text
        df.loc[i, 'User'] = tweet.user.name
        df.loc[i, 'User_statuses_count'] = tweet.user.statuses_count
        df.loc[i, 'user_followers'] = tweet.user.followers_count
        df.loc[i, 'User_location'] = tweet.user.location
        df.loc[i, 'User_verified'] = tweet.user.verified
        df.loc[i, 'fav_count'] = tweet.favorite_count
        df.loc[i, 'rt_count'] = tweet.retweet_count
        df.loc[i, 'tweet_date'] = tweet.created_at
        df.to_excel('{}.xlsx'.format(file_name))
        i = i+1
        if i == 1000:
            break
        else:
            pass

# %%
stream(data=["ipl T20 2020"],file_name='my_tweets')
# Out:
# 999

# %%
# !pip install textblob
# Out:
# ...
#   Using cached textblob-0.15.3-py2.py3-none-any.whl (636 kB)
# ...

# %%
from textblob import TextBlob

# %% [raw]
# Sentiment(polarity, subjectivity)
#
# Polarity score: [-1 , +1]
#
# Subjectivity: [0.0 , 1.0]
# where 0.0 is very Objective and 1.0 is very Subjective.

# %%
import re
def clean_tweet(tweet):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', tweet).split())

# %%
def analyze_sentiment(tweet):
    analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# %%
df['clean_tweet'] = df['Tweets'].apply(lambda x : clean_tweet(x))

# %%
df.head()
# Out:
#                                               Tweets  \
# 0  1000 T20 sixes ✅\nMatch fee deducted ❌\n\nDeta...
# 1  RT @WisdenCricket: Fans are not allowed at the...
# 2  RT @IExpressSports: #IPL2020 \n\nFrom Chris Ga...
# 3  Live Cricket IPL 2020 – MI vs. DC 51st T20 Liv...
# 4  RT @circleofcricket: Virat Kohli needs to hit ...
#
#                                        User User_statuses_count  \
# 0                                 GoodGamer                  85
# 1                                     Viraj               11116
# 2  🇮🇳 Bikram Samanta 🇮🇳 #StayHome #StaySafe               79108
# 3   SIAL TV | #PSL2020Final #IPL13 #IPL2020               10504
# 4                              Pranav Patel              359164
#
#   user_followers          User_location User_verified fav_count rt_count  \
# 0             47  Vancouver, BC, Canada         False         0        0
# 1            273                                False         0        9
# ...

# %%
df['Sentiment'] = df['clean_tweet'].apply(lambda x :analyze_sentiment(x))
df.head()
# Out:
#                                               Tweets  \
# 0  1000 T20 sixes ✅\nMatch fee deducted ❌\n\nDeta...
# 1  RT @WisdenCricket: Fans are not allowed at the...
# 2  RT @IExpressSports: #IPL2020 \n\nFrom Chris Ga...
# 3  Live Cricket IPL 2020 – MI vs. DC 51st T20 Liv...
# 4  RT @circleofcricket: Virat Kohli needs to hit ...
#
#                                        User User_statuses_count  \
# 0                                 GoodGamer                  85
# 1                                     Viraj               11116
# 2  🇮🇳 Bikram Samanta 🇮🇳 #StayHome #StaySafe               79108
# 3   SIAL TV | #PSL2020Final #IPL13 #IPL2020               10504
# 4                              Pranav Patel              359164
#
#   user_followers          User_location User_verified fav_count rt_count  \
# 0             47  Vancouver, BC, Canada         False         0        0
# 1            273                                False         0        9
# ...

# %%
n = 1
print("Original tweet:\n",df['Tweets'][n])
print()
print("Clean tweet:\n",df['clean_tweet'][n])
print()
print("Sentiment of the tweet:\n",df['Sentiment'][n])
# Out:
# Original tweet:
#  RT @WisdenCricket: Fans are not allowed at the IPL this year, but that hasn't influenced viewing figures in the UK.
#
# https://t.co/kRRo9Xxn5x
#
# Clean tweet:
#  RT Fans are not allowed at the IPL this year but that hasn t influenced viewing figures in the UK
#
# Sentiment of the tweet:
#  Neutral

# %%
df[df.Sentiment == 'Positive'].shape[0]
# Out:
# 774

# %%
df[df.Sentiment == 'Neutral'].shape[0]
# Out:
# 189

# %%
df[df.Sentiment == 'Negative'].shape[0]
# Out:
# 37
